# %% [markdown]
# # Data Lake on S3

# %%
from pyspark.sql import SparkSession

#import databricks.koalas as ks
import os
import configparser


from datetime import datetime

from pyspark.sql.functions import udf, col
from pyspark.sql.functions import year, month, dayofmonth, hour, weekofyear, date_format

# %% [markdown]
# # Make sure that your AWS credentials are loaded as env vars

# %%
config = configparser.ConfigParser()

#Normally this file should be in ~/.aws/credentials
config.read('dl.cfg')

os.environ["AWS_ACCESS_KEY_ID"]= config['AWS']['AWS_ACCESS_KEY_ID']
os.environ["AWS_SECRET_ACCESS_KEY"]= config['AWS']['AWS_SECRET_ACCESS_KEY']

# %% [markdown]
# # Create spark session with hadoop-aws package

# %%
spark = SparkSession.builder\
                    .config("spark.jars.packages","org.apache.hadoop:hadoop-aws:2.7.0")\
                     .getOrCreate()

# %% [markdown]
# # Load data from S3

# %%
input_data = "s3a://udacity-dend/"
output_data = "s3a://project4dend/"

# %%
#kdf = ks.read_json("data/song_data/*/*/*/*.json")# s3a://udacity-dend/song_data/*/*/*/*.json to read the whole data

# get filepath to song data file
#song_data = input_data + "data/song_data/A/B/C/*.json"
    
    # read song data file
df = spark.read.json("data/song_data/A/B/C/*.json")

# %%
#kdf.dtypes
df.head()
 # extract columns to create songs table
songs_table = df.select("song_id","title","artist_id","year","duration").drop_duplicates()
songs_table
# Out:
# DataFrame[song_id: string, title: string, artist_id: string, year: bigint, duration: double]

# %%
songs_table.write.parquet("songs/", mode="overwrite", partitionBy=["year","artist_id"])
 
    # extract columns to create artists table
artists_table = df.select("artist_id","artist_name","artist_location","artist_latitude","artist_longitude").drop_duplicates()
    
    # write artists table to parquet files
artists_table.write.parquet("artists/", mode="overwrite")

# %%
artists_table
# Out:
# DataFrame[artist_id: string, artist_name: string, artist_location: string, artist_latitude: double, artist_longitude: double]

# %% [markdown]
# # saving the data

# %%
songs_table = (ks.sql('''
               SELECT 
               DISTINCT
               row_number() over (ORDER BY year,title,artist_id) id,
               title,
               artist_id,
               year,
               duration
               FROM 
                   {kdf}''')
              )


songs_table
# Out:
#     id                                              title           artist_id  year   duration
# 0    1      A Whiter Shade Of Pale (Live @ Fillmore West)  ARLTWXK1187FB5A3F8     0  326.00771
# 1    2                                    Amor De Cabaret  ARKRRTF1187B9984DA     0  177.47546
# 2    3                                     Auguri Cha Cha  ARHHO3O1187B989413     0  191.84281
# 3    4                                    Baby Come To Me  AR9AWNF1187B9AB0B4     0  236.93016
# 4    5                         Broken-Down Merry-Go-Round  ARQGYP71187FB44566     0  151.84934
# 5    6                                 Clementina Santafè  ARGCY1Y1187B9A4FA5     0  153.33832
# 6    7                                        Den Pai Alo  AROGWRA122988FEE45     0  243.82649
# 7    8                                Der Kleine Dompfaff  ARJIE2Y1187B994AB7     0  152.92036
# 8    9                                       Drop of Rain  AR10USD1187B99F3F1     0  189.57016
# 9   10                      Erica (2005 Digital Remaster)  AREDBBQ1187B98AFF5     0  138.63138
# 10  11                   Get Your Head Stuck On Your Neck  AREDL271187FB40F44     0   45.66159
# 11  12                                 Got My Mojo Workin  ARAGB2O1187FB3A161     0  338.23302
# 12  13                                          High Tide  ARIG6O41187B988BDD     0  228.59710
# 13  14                                   I Didn't Mean To  ARD7TVE1187B99BFB1     0  218.93179
# 14  15                  Insatiable (Instrumental Version)  ARNTLGG11E2835DDB9     0  266.39628
# 15  16                               It Wont Be Christmas  ARMBR4Y1187B9990EB     0  241.47546
# 16  17                                       Kassie Jones  ARI3BMM1187FB4255E     0  220.78649
# 17  18                              Keepin It Real (Skit)  ARD0S291187B9B7BF5     0  114.78159
# 18  19                            Knocked Out Of The Park  ARQ9BO41187FB5CF1F     0  183.17016
# 19  20                        Kutt Free (DJ Volume Remix)  ARNNKDK1187B98BBD5     0  407.37914
# 20  21                                           La Culpa  ARL7K851187B99ACD2     0  226.35057
# 21  22                    Laws Patrolling (Album Version)  AREBBGV1187FB523D2     0  173.66159
# 22  23                                        Living Hell  AREVWGE1187B9B890A     0  282.43546
# 23  24                                  Loaded Like A Gun  ARBGXIG122988F409D     0  173.19138
# 24  25                              Made Like This (Live)  ARGIWFO1187B9B55B7     0  225.09669
# 25  26                                      Midnight Star  ARULZCI1241B9C8611     0  335.51628
# 26  27                              Music is what we love  AR051KA1187B98B2FF     0  261.51138
# 27  28                                            OAKtown  ARD7TVE1187B99BFB1     0  259.44771
# 28  29                                 Rumba De Barcelona  AR7SMBG1187B9B9066     0  218.38322
# 29  30                                        Salt In NYC  ARKULSX1187FB45F84     0  424.12363
# 30  31                                     Setanta matins  AR5KOSW1187FB35FF4     0  269.58322
# 31  32                               Sohna Nee Sohna Data  AR1ZHYZ1187FB3C717     0  599.24853
# 32  33                        Sonnerie lalaleulé hi houuu  ARGSAFR1269FB35070     0   29.54404
# 33  34                    Sono andati? Fingevo di dormire  ARDR4AC1187FB371A1     0  511.16363
# 34  35           Streets On Fire (Explicit Album Version)  ARPFHN61187FB575F6     0  279.97995
# 35  36                                  Superconfidential  ARNTLGG11E2835DDB9     0  338.31138
# 36  37                                    Synthetic Dream  ARNPAGP1241B9C7FD4     0  165.69424
# 37  38                                  The Emperor Falls  AR1Y2PT1187FB5B9CE     0  484.62322
# 38  39        The Moon And I (Ordinary Day Album Version)  ARKFYS91187B98E58F     0  267.70240
# 39  40                           The Urgency (LP Version)  ARC43071187B990240     0  245.21098
# 40  41                               Wessex Loses a Bride  ARI2JSK1187FB496EF     0  111.62077
# 41  42                      Wild Rose (Back 2 Basics Mix)  AR36F9J1187FB406F1     0  230.71302
# 42  43                                    Young Boy Blues  ARGSJW91187B9B1D6B     0  218.77506
# 43  44                               Crazy Mixed Up World  ARH4Z031187B9A71F2  1961  156.39465
# 44  45                                    Twist and Shout  ARAJPHH1187FB5566A  1964  164.80608
# 45  46                                          Soul Deep  ARMJAGH1187FB546F3  1969  148.03546
# 46  47                       Do You Finally Need A Friend  ARB29H41187B98F0EF  1972  342.56934
# 47  48                                    Something Girls  AR7G5I41187FB4CE6C  1982  233.40363
# 48  49                                         Pink World  AR8ZCNI1187B9A069B  1984  269.81832
# 49  50                     James (Hold The Ladder Steady)  AR47JEX1187B995D81  1985  124.86485
# 50  51                            Tonight Will Be Alright  ARIK43K1187B9AE54C  1986  307.38240
# 51  52                                           Floating  ARD842G1187B997376  1987  491.12771
# 52  53                         It Makes No Difference Now  AR0RCMP1187FB3F427  1992  133.32853
# 53  54                                  Blessed Assurance  AR7ZKHQ1187B98DD73  1993  270.60200
# 54  55                     A Higher Place (Album Version)  ARBEBBY1187B9B43DB  1994  236.17261
# 55  56                      The Ballad Of Sleeping Beauty  ARNF6401187FB57032  1994  305.16200
# 56  57                                     Spanish Grease  AROUOZZ1187B9ABE51  1997  168.25424
# 57  58                                  ¿Dónde va Chichi?  ARGUVEV1187B98BA17  1997  313.12934
# 58  59                                   Larger Than Life  AR3JMC51187B9AE49D  1999  236.25098
# 59  60  I Hold Your Hand In Mine [Live At Royal Albert...  ARPBNLO1187FB3D52F  2000   43.36281
# 60  61                                          Prognosis  ARWB3G61187FB49404  2000  363.85914
# 61  62                                              Intro  AR558FS1187FB45658  2003   75.67628
# 62  63                                        Native Soul  AR0IAWL1187B9A96D0  2003  197.19791
# 63  64                                  Caught In A Dream  ARYKCQI1187FB3B18F  2004  290.29832
# 64  65                                     Harajuku Girls  ARVBRGZ1187FB4675A  2004  290.55955
# 65  66                                  Jenny Take a Ride  ARP6N5A1187B99D1A3  2004  207.43791
# 66  67                    Setting Fire to Sleeping Giants  ARMAC4T1187FB3FA4C  2004  207.77751
# 67  68  I Think My Wife Is Running Around On Me (Taco ...  ARDNS031187B9924F0  2005  186.48771
# 68  69                                          Ten Tonne  AR62SOJ1187FB47BB5  2005  337.68444
# 69  70                                     Face the Ashes  ARXR32B1187FB57099  2007  209.60608
# 70  71                                      City Slickers  AR8IEZO1187B99055E  2008  149.86404

# %%
songs_table.shape
# Out:
# (71, 5)

# %% [markdown]
# ### Apache Parquet Introduction
#
# Apache Parquet is a columnar file format that provides optimizations to speed up queries and is a far more efficient file format than CSV or JSON, supported by many data processing systems.
#
#
#
#
# ### Spark Write DataFrame to Parquet file format
#
# Using spark.write.parquet() function we can write Spark DataFrame to Parquet file.

# %% [markdown]
# ### Spark parquet partition – Improving performance
#
# > Partitioning is a feature of many databases and data processing frameworks and it is key to make jobs work at scale. We can do a parquet file partition using spark partitionBy function.
#
# > Parquet Partition creates a folder hierarchy for each spark partition; we have mentioned the first partition as year followed by artist_id hence, it creates a artist_id folder inside the year folder.

# %%
    
(songs_table
 .to_spark()
 .write
 .partitionBy("year", "artist_id")
 .parquet('songs/')
)

# %% [markdown]
# ## Deployment

# %% [markdown]
# 1. Install `awscli`
#
# 2. run `aws configure`
#     * AWS Access Key ID :
#     * AWS Secret Access Key :
#     * Default region name: `us-west-2`
#     * Default output format : `json`
#
# 3. **copy all the necessary files to an s3 bucket**
#
#     * Ex: `aws s3 cp <filename> s3://<bucket_name>`

# %% [markdown]
# 4. **Run EMR create script with the etl job**
#
# ```
# aws emr create-cluster --name "Spark cluster with step" \
#     --release-label emr-5.30.1 \
#     --applications Name=Spark \
#     --log-uri s3://dendsparktutorial/logs/ \
#     --ec2-attributes KeyName=emr-key \
#     --instance-type m5.xlarge \
#     --instance-count 3 \
#     --bootstrap-actions Path=s3://dendsparktutorial/emr_bootstrap.sh \
#     --steps Type=Spark,Name="Spark program",ActionOnFailure=CONTINUE,Args=[--deploy-mode,cluster,--master,yarn,s3://dendsparktutorial/src/koalas_etl.py] \
#     --use-default-roles \
#     --auto-terminate
# ```
